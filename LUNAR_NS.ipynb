# %%
import numpy as np
np.random.seed(0)
import matplotlib.pyplot as plt
import gym
import csv
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable

# %%
class Net(nn.Module):
    def __init__(self, input_size, output_size, n_hidden=16):
        super(Net, self).__init__()
        self.linear1 = nn.Linear(input_size, n_hidden, bias=True)
        self.tanh1 = nn.Tanh()
        self.linear2 = nn.Linear(n_hidden, output_size)
        self.sigmoid = nn.Sigmoid()
    def forward(self, x):
        x = self.linear1(x)
        x = self.tanh1(x)
        x = self.linear2(x)
        x = self.sigmoid(x)
        return x

def get_action(net, obs):
    return net(torch.from_numpy(obs.copy()).float()).detach().numpy().argmax()

def evaluate(net):
    obs = env.reset()
    done = False
    total_reward = 0
    while not done:
        action = get_action(net, obs)
        obs, reward, done, _ = env.step(action)
        total_reward += reward
    return total_reward

def fitness_function(net, episodes=1):
    return np.mean([evaluate(net) for _ in range(episodes)])

def compute_fitness(population):
    return np.array([fitness_function(individual) for individual in population])

def get_fittest(population, fitness_scores):
    return population[fitness_scores.argmax()]

# %%
def behaviour(net):
    obs = env.reset()
    done = False
    while not done:
        action = get_action(net, obs)
        obs, reward, done, _ = env.step(action)
    return obs

def similarity(net1, net2):
    b1, b2 = behaviour(net1), behaviour(net2)
    return np.sum((b1 - b2)**2)

def compute_novelty(population, k=3):
    distances = []
    n = len(population)
    for i in range(n):
        distance_i = sorted([similarity(population[i], population[j]) for j in range(n) if i != j])[:k]
        distances.append(np.mean(distance_i))
    return distances

def get_novel_subpopulation(population, novelty_scores):
    return population[novelty_scores.argmax()]

def select_most_novel(population, novelty_scores, k=0.5):
    return population[np.argsort(novelty_scores)[-int(len(population) * k):]]

# %%
import copy

def perform_reproduction(subpopulation):
    num_children = population_size - len(subpopulation)
    parents = np.random.choice(subpopulation, num_children)
    return np.append(subpopulation, [copy.deepcopy(p) for p in parents], axis=0)

# %%
from torch.nn.utils import parameters_to_vector, vector_to_parameters

def get_params(net):
    return parameters_to_vector(net.parameters())

def mutate_params(net, sigma=0.1):
    mutated_params = get_params(net) + torch.normal(0, sigma, size=get_params(net).data.shape)
    vector_to_parameters(mutated_params, net.parameters())

def perform_mutation(population, sigma=0.1):
    for individual in population:
        mutate_params(individual, sigma=0.1)
    return population

# %%
# Novelty Search hyperparameters
population_size = 20
num_generations = 100
top_k = 0.2
mutation_sigma = 0.1
k_nearest = 3

# CartPole environment initialisation
env = gym.make('LunarLander-v2')

# Neural network hyperparameters
input_size = env.observation_space.shape[0]
output_size = env.action_space.n
n_hidden = 16

# Process 1: Generate the initial population.
population = np.array([Net(input_size, output_size, n_hidden) for _ in range(population_size)])

# Misc: Experimental tracking
scores = []
fittests = []

with open("LUNAR_NS_train_scores.csv", "w") as csvfile:
    header = ["generation", "average fitness", "maximum fitness"]
    writer = csv.writer(csvfile, delimiter=',')
    writer.writerow(header)

    for gen in range(num_generations):

      # Process 2: Compute the novelty of individuals with respect to closest neighbours in the population.
        novelty_scores = compute_novelty(population, k=k_nearest)

      # Process 3: Select the most novel individuals.
        novel_subpopulation = select_most_novel(population, novelty_scores, k=top_k)

      # Misc: Experimental tracking
        fitness_scores = compute_fitness(population)
        genAvgFit = np.mean(fitness_scores)
        fittest = get_fittest(population, fitness_scores) #the fittest one of the population
        fittests.append(fittest)
        max_fitness_pop = max(fitness_scores)
        scores.append(max_fitness_pop)
        
        print("Generation : %3d |  Avg Fitness : %5.0f  |  Max Fitness : %5.0f  " % (gen+1, genAvgFit, max_fitness_pop))
        writer.writerow([gen+1, genAvgFit, max_fitness_pop])

      # Process 4: Perform reproduction between parents.
        children = perform_reproduction(novel_subpopulation)
        population = perform_mutation(children, sigma=mutation_sigma)
# Out:
# Generation :   1 |  Avg Fitness :  -531  |  Max Fitness :    32
# Generation :   2 |  Avg Fitness :  -449  |  Max Fitness :  -184
# Generation :   3 |  Avg Fitness :  -486  |  Max Fitness :  -249
# Generation :   4 |  Avg Fitness :  -658  |  Max Fitness :  -216
# Generation :   5 |  Avg Fitness :  -536  |  Max Fitness :   -94
# Generation :   6 |  Avg Fitness :  -651  |  Max Fitness :  -408
# Generation :   7 |  Avg Fitness :  -597  |  Max Fitness :  -254
# Generation :   8 |  Avg Fitness :  -876  |  Max Fitness :  -402
# Generation :   9 |  Avg Fitness :  -797  |  Max Fitness :  -365
# Generation :  10 |  Avg Fitness :  -743  |  Max Fitness :  -535
# Generation :  11 |  Avg Fitness :  -736  |  Max Fitness :  -195
# Generation :  12 |  Avg Fitness :  -549  |  Max Fitness :   -65
# Generation :  13 |  Avg Fitness :  -726  |  Max Fitness :  -143
# Generation :  14 |  Avg Fitness :  -627  |  Max Fitness :  -329
# Generation :  15 |  Avg Fitness :  -707  |  Max Fitness :  -242
# Generation :  16 |  Avg Fitness :  -761  |  Max Fitness :  -380
# Generation :  17 |  Avg Fitness :  -952  |  Max Fitness :  -412
# Generation :  18 |  Avg Fitness :  -847  |  Max Fitness :  -486
# Generation :  19 |  Avg Fitness :  -781  |  Max Fitness :  -252
# Generation :  20 |  Avg Fitness :  -993  |  Max Fitness :  -425
# Generation :  21 |  Avg Fitness :  -919  |  Max Fitness :  -420
# Generation :  22 |  Avg Fitness :  -769  |  Max Fitness :  -307
# Generation :  23 |  Avg Fitness :  -767  |  Max Fitness :  -474
# Generation :  24 |  Avg Fitness :  -725  |  Max Fitness :  -418
# Generation :  25 |  Avg Fitness :  -783  |  Max Fitness :  -328
# Generation :  26 |  Avg Fitness :  -861  |  Max Fitness :  -298
# Generation :  27 |  Avg Fitness :  -902  |  Max Fitness :  -400
# Generation :  28 |  Avg Fitness :  -616  |  Max Fitness :  -235
# Generation :  29 |  Avg Fitness :  -909  |  Max Fitness :  -395
# Generation :  30 |  Avg Fitness :  -778  |  Max Fitness :  -431
# Generation :  31 |  Avg Fitness :  -639  |  Max Fitness :  -116
# Generation :  32 |  Avg Fitness : -1044  |  Max Fitness :  -230
# Generation :  33 |  Avg Fitness :  -970  |  Max Fitness :  -249
# Generation :  34 |  Avg Fitness :  -829  |  Max Fitness :  -436
# Generation :  35 |  Avg Fitness :  -634  |  Max Fitness :  -365
# Generation :  78 |  Avg Fitness :  -677  |  Max Fitness :  -100
# Generation :  79 |  Avg Fitness :  -855  |  Max Fitness :  -360
# Generation :  80 |  Avg Fitness :  -703  |  Max Fitness :  -377
# Generation :  81 |  Avg Fitness : -1230  |  Max Fitness :  -305
# Generation :  82 |  Avg Fitness :  -766  |  Max Fitness :  -404
# Generation :  83 |  Avg Fitness :  -833  |  Max Fitness :  -439
# Generation :  84 |  Avg Fitness :  -993  |  Max Fitness :  -425
# Generation :  85 |  Avg Fitness :  -781  |  Max Fitness :   -93
# Generation :  86 |  Avg Fitness :  -874  |  Max Fitness :  -104
# Generation :  87 |  Avg Fitness :  -971  |  Max Fitness :  -351
# Generation :  88 |  Avg Fitness : -1378  |  Max Fitness :  -348
# Generation :  89 |  Avg Fitness :  -685  |  Max Fitness :  -446
# Generation :  90 |  Avg Fitness :  -713  |  Max Fitness :  -378
# Generation :  91 |  Avg Fitness : -1034  |  Max Fitness :  -360
# Generation :  92 |  Avg Fitness :  -858  |  Max Fitness :  -412
# Generation :  93 |  Avg Fitness :  -916  |  Max Fitness :  -376
# Generation :  94 |  Avg Fitness : -1197  |  Max Fitness :  -434
# Generation :  95 |  Avg Fitness :  -881  |  Max Fitness :  -177
# Generation :  96 |  Avg Fitness :  -860  |  Max Fitness :    -5
# Generation :  97 |  Avg Fitness :  -959  |  Max Fitness :  -142
# Generation :  98 |  Avg Fitness :  -631  |  Max Fitness :   -96
# Generation :  99 |  Avg Fitness :  -565  |  Max Fitness :  -348
# Generation : 100 |  Avg Fitness :  -772  |  Max Fitness :  -344

# %%
# Misc: Experimental tracking
plt.plot(np.arange(num_generations), scores)
plt.show()

# %%
plt.xlabel("Novelty Score")
plt.ylabel("Fitness Score")
plt.scatter(novelty_scores, fitness_scores)
plt.show()

# %%
fit = np.argmax(scores) #index of fittest individual
fittest_overall = fittests[fit]

# %%
PLAY = 100

with open("LUNAR_NS_play_scores.csv", "w") as csvfile2:
    writer = csv.writer(csvfile2, delimiter=',')
    header = ["attempt", "score"]
    writer.writerow(header)
    
    for attempt in range(PLAY):
        obs = env.reset()
        rewards = 0
        for step in range(500):
            action = get_action(fittest_overall, obs)
            obs, reward, done, _ = env.step(action)
            rewards += reward
            if done:
                obs = env.reset()
                break
        print("Attempt : %3d |  Score : %4.0f  " % (attempt+1, rewards) )
        writer.writerow([attempt+1, rewards])
# Out:
# Attempt :   1 |  Score : -130
# Attempt :   2 |  Score : -144
# Attempt :   3 |  Score : -132
# Attempt :   4 |  Score : -140
# Attempt :   5 |  Score :  -83
# Attempt :   6 |  Score : -195
# Attempt :   7 |  Score :  -94
# Attempt :   8 |  Score : -151
# Attempt :   9 |  Score : -190
# Attempt :  10 |  Score :  -84
# Attempt :  11 |  Score : -155
# Attempt :  12 |  Score : -186
# Attempt :  13 |  Score : -112
# Attempt :  14 |  Score : -111
# Attempt :  15 |  Score : -172
# Attempt :  16 |  Score : -204
# Attempt :  17 |  Score : -136
# Attempt :  18 |  Score : -139
# Attempt :  19 |  Score :  -22
# Attempt :  20 |  Score : -145
# Attempt :  21 |  Score : -174
# Attempt :  22 |  Score : -127
# Attempt :  23 |  Score : -155
# Attempt :  24 |  Score : -149
# Attempt :  25 |  Score : -180
# Attempt :  26 |  Score : -104
# Attempt :  27 |  Score :  -93
# Attempt :  28 |  Score : -110
# Attempt :  29 |  Score : -107
# Attempt :  30 |  Score :   28
# Attempt :  31 |  Score :  -81
# Attempt :  32 |  Score : -151
# Attempt :  33 |  Score : -145
# Attempt :  34 |  Score : -136
# Attempt :  35 |  Score : -165
# Attempt :  36 |  Score : -132
# Attempt :  37 |  Score : -124
# Attempt :  38 |  Score : -110
# Attempt :  39 |  Score :  -74
# Attempt :  40 |  Score : -115
# Attempt :  41 |  Score :  -14
# Attempt :  42 |  Score : -145
# Attempt :  43 |  Score : -200
# Attempt :  44 |  Score : -122
# Attempt :  45 |  Score : -204
# Attempt :  46 |  Score : -151
# Attempt :  47 |  Score : -119
# Attempt :  48 |  Score : -147
# Attempt :  49 |  Score : -153
# Attempt :  50 |  Score : -173
# Attempt :  51 |  Score : -119
# Attempt :  52 |  Score : -154
# Attempt :  53 |  Score : -180
# Attempt :  54 |  Score : -120
# Attempt :  55 |  Score : -139
# Attempt :  56 |  Score :  -81
# Attempt :  57 |  Score : -145
# Attempt :  58 |  Score : -138
# Attempt :  59 |  Score : -130
# Attempt :  60 |  Score :  -89
# Attempt :  61 |  Score : -115
# Attempt :  62 |  Score : -122
# Attempt :  63 |  Score :  -87
# Attempt :  64 |  Score : -160
# Attempt :  65 |  Score : -148
# Attempt :  66 |  Score : -133
# Attempt :  67 |  Score : -321
# Attempt :  68 |  Score : -121
# Attempt :  69 |  Score : -153
# Attempt :  70 |  Score : -123
# Attempt :  71 |  Score : -158
# Attempt :  72 |  Score : -131
# Attempt :  73 |  Score : -131
# Attempt :  74 |  Score : -148
# Attempt :  75 |  Score : -143
# Attempt :  76 |  Score : -141
# Attempt :  77 |  Score : -111
# Attempt :  78 |  Score : -141
# Attempt :  79 |  Score : -112
# Attempt :  80 |  Score :   16
# Attempt :  81 |  Score : -118
# Attempt :  82 |  Score : -111
# Attempt :  83 |  Score : -102
# Attempt :  84 |  Score : -178
# Attempt :  85 |  Score : -148
# Attempt :  86 |  Score : -157
# Attempt :  87 |  Score :  -85
# Attempt :  88 |  Score : -135
# Attempt :  89 |  Score : -157
# Attempt :  90 |  Score : -138
# Attempt :  91 |  Score : -146
# Attempt :  92 |  Score : -133
# Attempt :  93 |  Score : -120
# Attempt :  94 |  Score : -117
# Attempt :  95 |  Score : -111
# Attempt :  96 |  Score : -133
# Attempt :  97 |  Score : -130
# Attempt :  98 |  Score : -159
# Attempt :  99 |  Score : -142
# Attempt : 100 |  Score : -191
