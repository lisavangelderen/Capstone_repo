# %%
import gym
import csv
import random
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import RMSprop, Adam
import numpy as np
import matplotlib.pyplot as plt
from collections import deque
from statistics import mean
import h5py

# %%
LEARNING_RATE = 1e-3
MAX_MEMORY = 1000000
BATCH_SIZE = 20
GAMMA = 0.95
EXPLORATION_DECAY = 0.995
EXPLORATION_MIN = 0.01

# %%
class ScoreEvaluator:

    def __init__(self, max_len, average_of_last_runs, model = None):
        self.max_len = max_len
        self.score_table = deque(maxlen=self.max_len)
        self.model = model
        self.average_of_last_runs = average_of_last_runs

    def store_score(self, episode, step):
        self.score_table.append([episode, step])

    def evaluation_score(self, title = "Training"):
        return self.score_table
        

class Network:

    def __init__(self, observation_space, action_space):

        self.action_space = action_space
        self.memory = deque(maxlen=MAX_MEMORY)
        self.exploration_rate = 1.0

        self.model = Sequential()
        self.model.add(Dense(32, input_shape=(observation_space,), activation='relu'))
        self.model.add(Dense(32, activation='relu'))
        self.model.add(Dense(self.action_space, activation='linear'))
        self.model.compile(loss='mse', optimizer=Adam(lr=LEARNING_RATE))

    def add_to_memory(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def take_action(self, state):
        if np.random.rand() < self.exploration_rate:
            return random.randrange(0, self.action_space)
        q_values = self.model.predict(state)
        return np.argmax(q_values[0])

    def experience_replay(self):
        if len(self.memory) < BATCH_SIZE:
            return
        else:
            minibatch = random.sample(self.memory, BATCH_SIZE)
            for state, action, reward, state_next, done in minibatch:
                Q = reward
                if not done:
                    Q = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))
                Q_values = self.model.predict(state)
                Q_values[0][action] = Q
                self.model.fit(state, Q_values, verbose=0)
            self.exploration_rate *= EXPLORATION_DECAY
            self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)

    def get_model(self):
        return self.model


class TrainSolver:

    def __init__(self, max_episodes):
        self.max_episodes = max_episodes
        self.score_table = deque(maxlen=400)
        self.average_of_last_runs = None
        self.model = None
        self.play_episodes = 100
        env = gym.make('CartPole-v1')
        observation_space = env.observation_space.shape[0]
        action_space = env.action_space.n
        self.solver = Network(observation_space, action_space)

    def train(self):
        env = gym.make('CartPole-v1')
        observation_space = env.observation_space.shape[0]
        action_space = env.action_space.n

        print("---------------------------------")
        print("Solver starts")
        print("---------------------------------")

        self.model = self.solver.get_model()
        episode = 0
        score_eval = ScoreEvaluator(400, 50, self.model)
        while episode < self.max_episodes:

            episode += 1
            state = env.reset()
            state = np.reshape(state, [1, observation_space])
            step = 0
            while True:

                step += 1
                action = self.solver.take_action(state)
                state_next, reward, done, info = env.step(action)
                if not done:
                    reward = reward
                else:
                    reward = -reward
                state_next = np.reshape(state_next, [1, observation_space])
                self.solver.add_to_memory(state, action, reward, state_next, done)
                state = state_next

                if done:
                    print("Run: " + str(episode) + ", exploration: " + str(self.solver.exploration_rate) + ", score: " + str(step))
                    self.score_table.append([episode, step])
                    score_eval.store_score(episode, step)
                    break
                self.solver.experience_replay()
        
        train_scores = score_eval.evaluation_score("100 trains")
        with open("Cartpole_DQN_train_scores.csv", "w") as csvfile:
            header = ["episode", "score"]
            writer = csv.writer(csvfile, delimiter=',')
            writer.writerow(header)
            for i in train_scores:
                i = tuple(i)
                episode, score = i[0], i[1]
                writer.writerow([episode, score])

    def return_trained_model(self):
        return self.model

    def play(self, play_episodes=100, load_model=False, model_weights_dir=None, trained_model=None):

        self.play_episodes = play_episodes
        if load_model is not False:
            if model_weights_dir is None:
                print("Can't load specified model")
            elif trained_model is None:
                print("Please pass a valid model as a parameter")
            else:
                model = trained_model
                model.load(model_weights_dir)
        else:
            model = self.model

        env = gym.make('CartPole-v1')
        observation_space = env.observation_space.shape[0]
        action_space = env.action_space.n
        episode = 0
        score_eval = ScoreEvaluator(400, 100, model)
        while episode < self.play_episodes:

            episode += 1
            state = env.reset()
            state = np.reshape(state, [1, observation_space])
            step = 0
            while True:

                step += 1
                action = self.solver.take_action(state)
                state_next, reward, done, info = env.step(action)

                if not done:
                    reward = reward
                else:
                    reward = -reward
                state_next = np.reshape(state_next, [1, observation_space])
                self.solver.add_to_memory(state, action, reward, state_next, done)
                state = state_next

                if done:
                    print("Run: " + str(episode) + ", score: " + str(
                        step))
                    self.score_table.append([episode, step])
                    score_eval.store_score(episode, step)
                    break
                self.solver.experience_replay()
        
        play_scores = score_eval.evaluation_score("100 Plays")
        with open("Cartpole_DQN_play_scores.csv", "w") as csvfile:
            header = ["episode", "score"]
            writer = csv.writer(csvfile, delimiter=',')
            writer.writerow(header)
            for i in play_scores:
                i = tuple(i)
                episode, score = i[0], i[1]
                writer.writerow([episode, score])
                
    def save_model(self):
        self.model.save('cartpole_dqn_model.h5')


if __name__ == "__main__":
    trainer = TrainSolver(100)
    trainer.train()
    trainer.play(100)
    trainer.save_model()
# Out:
# ---------------------------------
# Solver starts
# ---------------------------------
# Run: 1, exploration: 1.0, score: 11
# Run: 2, exploration: 0.9511101304657719, score: 19
# Run: 3, exploration: 0.9091562615825302, score: 10
# Run: 4, exploration: 0.8647077305675338, score: 11
# Run: 5, exploration: 0.8265651079747222, score: 10
# Run: 6, exploration: 0.778312557068642, score: 13
# Run: 7, exploration: 0.7328768546436799, score: 13
# Run: 8, exploration: 0.6866430931872001, score: 14
# Run: 9, exploration: 0.6465587967553006, score: 13
# Run: 10, exploration: 0.6057704364907278, score: 14
# Run: 11, exploration: 0.5790496471185967, score: 10
# Run: 12, exploration: 0.5425201222922789, score: 14
# Run: 13, exploration: 0.49571413690105054, score: 19
# Run: 14, exploration: 0.46912134373457726, score: 12
# Run: 15, exploration: 0.42437208406280985, score: 21
# Run: 16, exploration: 0.4036245882390106, score: 11
# Run: 17, exploration: 0.38389143477919885, score: 11
# Run: 18, exploration: 0.33362200135903064, score: 29
# Run: 19, exploration: 0.3063705780533402, score: 18
# Run: 20, exploration: 0.2689348941735696, score: 27
# Run: 21, exploration: 0.25578670228422234, score: 11
# Run: 22, exploration: 0.24206491716205145, score: 12
# Run: 23, exploration: 0.2290792429684691, score: 12
# Run: 24, exploration: 0.22007483514733558, score: 9
# Run: 25, exploration: 0.20931540516921554, score: 11
# Run: 26, exploration: 0.2000824143909432, score: 10
# Run: 27, exploration: 0.18840216465300522, score: 13
# Run: 28, exploration: 0.1800916657318127, score: 10
# Run: 29, exploration: 0.16048131420416054, score: 24
# Run: 30, exploration: 0.14885748713096328, score: 16
# Run: 31, exploration: 0.14157986400593744, score: 11
# Run: 32, exploration: 0.13264825480308728, score: 14
# Run: 33, exploration: 0.1176130407830293, score: 25
# Run: 34, exploration: 0.09721483575406, score: 39
# Run: 35, exploration: 0.08838347664452084, score: 20
# Run: 36, exploration: 0.07797369223798889, score: 26
# Run: 37, exploration: 0.0712465030521374, score: 19
# Run: 38, exploration: 0.06254083169574957, score: 27
# Run: 39, exploration: 0.03147209942303359, score: 138
# Run: 40, exploration: 0.026275840769466357, score: 37
# Run: 41, exploration: 0.020246819920648168, score: 53
# Run: 42, exploration: 0.0175075817047932, score: 30
# Run: 43, exploration: 0.010929385683282892, score: 95
# Run: 44, exploration: 0.01, score: 52
# Run: 45, exploration: 0.01, score: 62
# Run: 46, exploration: 0.01, score: 63
# Run: 47, exploration: 0.01, score: 86
# Run: 48, exploration: 0.01, score: 181
# Run: 49, exploration: 0.01, score: 229
# Run: 50, exploration: 0.01, score: 250
# Run: 51, exploration: 0.01, score: 301
# Run: 52, exploration: 0.01, score: 153
# Run: 53, exploration: 0.01, score: 235
# Run: 54, exploration: 0.01, score: 246
# Run: 55, exploration: 0.01, score: 173
# Run: 56, exploration: 0.01, score: 174
# Run: 57, exploration: 0.01, score: 284
# Run: 58, exploration: 0.01, score: 173
# Run: 59, exploration: 0.01, score: 180
# Run: 60, exploration: 0.01, score: 206
# Run: 61, exploration: 0.01, score: 198
# Run: 62, exploration: 0.01, score: 215
# Run: 63, exploration: 0.01, score: 231
# Run: 64, exploration: 0.01, score: 168
# Run: 65, exploration: 0.01, score: 239
# Run: 66, exploration: 0.01, score: 184
# Run: 67, exploration: 0.01, score: 144
# Run: 68, exploration: 0.01, score: 248
# Run: 69, exploration: 0.01, score: 207
# Run: 70, exploration: 0.01, score: 221
# Run: 71, exploration: 0.01, score: 150
# Run: 72, exploration: 0.01, score: 218
# Run: 73, exploration: 0.01, score: 242
# Run: 74, exploration: 0.01, score: 181
# Run: 75, exploration: 0.01, score: 157
# Run: 76, exploration: 0.01, score: 300
# Run: 77, exploration: 0.01, score: 166
# Run: 78, exploration: 0.01, score: 197
# Run: 79, exploration: 0.01, score: 192
# Run: 80, exploration: 0.01, score: 259
# Run: 81, exploration: 0.01, score: 137
# Run: 82, exploration: 0.01, score: 108
# Run: 83, exploration: 0.01, score: 214
# Run: 84, exploration: 0.01, score: 185
# Run: 85, exploration: 0.01, score: 101
# Run: 86, exploration: 0.01, score: 136
# Run: 87, exploration: 0.01, score: 181
# Run: 88, exploration: 0.01, score: 178
# Run: 89, exploration: 0.01, score: 138
