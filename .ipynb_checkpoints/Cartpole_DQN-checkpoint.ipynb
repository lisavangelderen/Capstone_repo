# %% [markdown]
# The (adapted) code in this notebook comes from: https://github.com/siddharthkale97/CartPole-v1-DeepQ-AI/blob/master/DeepQcartpole.py

# %%
import gym
import csv
import random
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import RMSprop, Adam
import numpy as np
import matplotlib.pyplot as plt
from collections import deque
from statistics import mean
import h5py

# %%
LEARNING_RATE = 1e-3
MAX_MEMORY = 1000000
BATCH_SIZE = 20
GAMMA = 0.95
EXPLORATION_DECAY = 0.995
EXPLORATION_MIN = 0.01

# %%
class ScoreEvaluator:

    def __init__(self, max_len, average_of_last_runs, model = None):
        self.max_len = max_len
        self.score_table = deque(maxlen=self.max_len)
        self.model = model
        self.average_of_last_runs = average_of_last_runs

    def store_score(self, episode, step):
        self.score_table.append([episode, step])

    def evaluation_score(self, title = "Training"):
        return self.score_table
        

class Network:

    def __init__(self, observation_space, action_space):

        self.action_space = action_space
        self.memory = deque(maxlen=MAX_MEMORY)
        self.exploration_rate = 1.0

        self.model = Sequential()
        self.model.add(Dense(32, input_shape=(observation_space,), activation='relu'))
        self.model.add(Dense(32, activation='relu'))
        self.model.add(Dense(self.action_space, activation='linear'))
        self.model.compile(loss='mse', optimizer=Adam(lr=LEARNING_RATE))

    def add_to_memory(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def take_action(self, state):
        if np.random.rand() < self.exploration_rate:
            return random.randrange(0, self.action_space)
        q_values = self.model.predict(state)
        return np.argmax(q_values[0])

    def experience_replay(self):
        if len(self.memory) < BATCH_SIZE:
            return
        else:
            minibatch = random.sample(self.memory, BATCH_SIZE)
            for state, action, reward, state_next, done in minibatch:
                Q = reward
                if not done:
                    Q = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))
                Q_values = self.model.predict(state)
                Q_values[0][action] = Q
                self.model.fit(state, Q_values, verbose=0)
            self.exploration_rate *= EXPLORATION_DECAY
            self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)

    def get_model(self):
        return self.model


class TrainSolver:

    def __init__(self, max_episodes):
        self.max_episodes = max_episodes
        self.score_table = deque(maxlen=400)
        self.average_of_last_runs = None
        self.model = None
        self.play_episodes = 100
        env = gym.make('CartPole-v1')
        observation_space = env.observation_space.shape[0]
        action_space = env.action_space.n
        self.solver = Network(observation_space, action_space)

    def train(self):
        env = gym.make('CartPole-v1')
        observation_space = env.observation_space.shape[0]
        action_space = env.action_space.n

        print("---------------------------------")
        print("Solver starts")
        print("---------------------------------")

        self.model = self.solver.get_model()
        episode = 0
        score_eval = ScoreEvaluator(400, 50, self.model)
        with open("Cartpole_DQN_train_scores.csv", "w") as csvfile:
            header = ["episode", "epsilon", "score"]
            writer = csv.writer(csvfile, delimiter=',')
            writer.writerow(header)
            while episode < self.max_episodes:

                episode += 1
                state = env.reset()
                state = np.reshape(state, [1, observation_space])
                step = 0
                while True:

                    step += 1
                    action = self.solver.take_action(state)
                    state_next, reward, done, info = env.step(action)
                    if not done:
                        reward = reward
                    else:
                        reward = -reward
                    state_next = np.reshape(state_next, [1, observation_space])
                    self.solver.add_to_memory(state, action, reward, state_next, done)
                    state = state_next

                    if done:
                        print("Run: " + str(episode) + ", exploration: " + str(self.solver.exploration_rate) + ", score: " + str(step))
                        writer.writerow([episode, self.solver.exploration_rate, step])
                        self.score_table.append([episode, step])
                        score_eval.store_score(episode, step)
                        break
                    self.solver.experience_replay()

        train_scores = score_eval.evaluation_score("100 trains")
    

    def return_trained_model(self):
        return self.model

    def play(self, play_episodes=100, load_model=False, model_weights_dir=None, trained_model=None):

        self.play_episodes = play_episodes
        if load_model is not False:
            if model_weights_dir is None:
                print("Can't load specified model")
            elif trained_model is None:
                print("Please pass a valid model as a parameter")
            else:
                model = trained_model
                model.load(model_weights_dir)
        else:
            model = self.model

        env = gym.make('CartPole-v1')
        observation_space = env.observation_space.shape[0]
        action_space = env.action_space.n
        episode = 0
        score_eval = ScoreEvaluator(400, 100, model)
        while episode < self.play_episodes:

            episode += 1
            state = env.reset()
            state = np.reshape(state, [1, observation_space])
            step = 0
            while True:

                step += 1
                action = self.solver.take_action(state)
                state_next, reward, done, info = env.step(action)

                if not done:
                    reward = reward
                else:
                    reward = -reward
                state_next = np.reshape(state_next, [1, observation_space])
                self.solver.add_to_memory(state, action, reward, state_next, done)
                state = state_next

                if done:
                    print("Run: " + str(episode) + ", score: " + str(
                        step))
                    self.score_table.append([episode, step])
                    score_eval.store_score(episode, step)
                    break
                self.solver.experience_replay()
        
        play_scores = score_eval.evaluation_score("100 Plays")
        with open("Cartpole_DQN_play_scores.csv", "w") as csvfile:
            header = ["episode", "score"]
            writer = csv.writer(csvfile, delimiter=',')
            writer.writerow(header)
            for i in play_scores:
                i = tuple(i)
                episode, score = i[0], i[1]
                writer.writerow([episode, score])
                
    def save_model(self):
        self.model.save('cartpole_dqn_model.h5')


if __name__ == "__main__":
    trainer = TrainSolver(100)
    trainer.train()
    trainer.play(100)
    trainer.save_model()
# Out:
# ---------------------------------
# Solver starts
# ---------------------------------
# Run: 1, exploration: 1.0, score: 11
# Run: 2, exploration: 0.9416228069143757, score: 21
# Run: 3, exploration: 0.8911090557802088, score: 12
# Run: 4, exploration: 0.851801859600347, score: 10
# Run: 5, exploration: 0.7590483508202912, score: 24
# Run: 6, exploration: 0.7183288830986236, score: 12
# Run: 7, exploration: 0.6211445383053219, score: 30
# Run: 8, exploration: 0.5732736268885887, score: 17
# Run: 9, exploration: 0.531750826943791, score: 16
# Run: 10, exploration: 0.5057535983897912, score: 11
# Run: 11, exploration: 0.46912134373457726, score: 16
# Run: 12, exploration: 0.3543053533848483, score: 57
# Run: 13, exploration: 0.33362200135903064, score: 13
# Run: 14, exploration: 0.29580711868545667, score: 25
# Run: 15, exploration: 0.2570720625972084, score: 29
# Run: 16, exploration: 0.23489314109365644, score: 19
# Run: 17, exploration: 0.19709615934585656, score: 36
# Run: 18, exploration: 0.182820281282489, score: 16
# Run: 19, exploration: 0.1678868750508869, score: 18
# Run: 20, exploration: 0.14444721332374086, score: 31
# Run: 21, exploration: 0.11702497557911415, score: 43
# Run: 22, exploration: 0.10692863247165257, score: 19
# Run: 23, exploration: 0.07955285615946175, score: 60
# Run: 24, exploration: 0.0716045256805401, score: 22
# Run: 25, exploration: 0.06191698689958447, score: 30
# Run: 26, exploration: 0.05685938874076987, score: 18
# Run: 27, exploration: 0.045605554379880814, score: 45
# Run: 28, exploration: 0.03657912327863173, score: 45
# Run: 29, exploration: 0.029192542808371146, score: 46
# Run: 30, exploration: 0.013289101019874787, score: 158
# Run: 31, exploration: 0.01, score: 136
# Run: 32, exploration: 0.01, score: 137
# Run: 33, exploration: 0.01, score: 128
# Run: 34, exploration: 0.01, score: 124
# Run: 35, exploration: 0.01, score: 137
# Run: 36, exploration: 0.01, score: 225
# Run: 37, exploration: 0.01, score: 262
# Run: 38, exploration: 0.01, score: 205
# Run: 39, exploration: 0.01, score: 263
# Run: 40, exploration: 0.01, score: 200
# Run: 41, exploration: 0.01, score: 183
# Run: 42, exploration: 0.01, score: 216
# Run: 43, exploration: 0.01, score: 168
# Run: 44, exploration: 0.01, score: 238
# Run: 45, exploration: 0.01, score: 222
# Run: 46, exploration: 0.01, score: 186
# Run: 47, exploration: 0.01, score: 239
# Run: 48, exploration: 0.01, score: 195
# Run: 49, exploration: 0.01, score: 222
# Run: 50, exploration: 0.01, score: 247
# Run: 51, exploration: 0.01, score: 234
# Run: 52, exploration: 0.01, score: 194
# Run: 53, exploration: 0.01, score: 258
# Run: 54, exploration: 0.01, score: 154
# Run: 55, exploration: 0.01, score: 278
# Run: 56, exploration: 0.01, score: 192
# Run: 57, exploration: 0.01, score: 134
# Run: 58, exploration: 0.01, score: 228
# Run: 59, exploration: 0.01, score: 125
# Run: 60, exploration: 0.01, score: 89
# Run: 61, exploration: 0.01, score: 118
# Run: 62, exploration: 0.01, score: 155
# Run: 63, exploration: 0.01, score: 156
# Run: 64, exploration: 0.01, score: 187
# Run: 65, exploration: 0.01, score: 191
# Run: 66, exploration: 0.01, score: 142
# Run: 67, exploration: 0.01, score: 266
# Run: 68, exploration: 0.01, score: 207
# Run: 69, exploration: 0.01, score: 180
# Run: 70, exploration: 0.01, score: 268
# Run: 71, exploration: 0.01, score: 174
# Run: 72, exploration: 0.01, score: 168
# Run: 73, exploration: 0.01, score: 151
# Run: 74, exploration: 0.01, score: 188
# Run: 75, exploration: 0.01, score: 135
# Run: 76, exploration: 0.01, score: 193
# Run: 77, exploration: 0.01, score: 189
# Run: 78, exploration: 0.01, score: 138
# Run: 79, exploration: 0.01, score: 232
# Run: 80, exploration: 0.01, score: 339
# Run: 81, exploration: 0.01, score: 154
# Run: 82, exploration: 0.01, score: 145
# Run: 83, exploration: 0.01, score: 239
# Run: 84, exploration: 0.01, score: 191
# Run: 85, exploration: 0.01, score: 211
# Run: 86, exploration: 0.01, score: 146
# Run: 87, exploration: 0.01, score: 147
# Run: 88, exploration: 0.01, score: 158
# Run: 89, exploration: 0.01, score: 253
# Run: 90, exploration: 0.01, score: 276
# Run: 91, exploration: 0.01, score: 162
# Run: 92, exploration: 0.01, score: 280
# Run: 93, exploration: 0.01, score: 300
# Run: 94, exploration: 0.01, score: 191
# Run: 95, exploration: 0.01, score: 164
# Run: 96, exploration: 0.01, score: 164
# Run: 97, exploration: 0.01, score: 189
# Run: 98, exploration: 0.01, score: 220
# Run: 99, exploration: 0.01, score: 179
# Run: 100, exploration: 0.01, score: 134
# Run: 1, score: 214
# Run: 2, score: 211
# Run: 3, score: 188
# Run: 4, score: 228
# Run: 5, score: 264
# Run: 6, score: 299
# Run: 7, score: 240
# Run: 8, score: 188
# Run: 9, score: 128
# Run: 10, score: 174
# Run: 11, score: 293
# Run: 12, score: 144
# Run: 13, score: 242
# Run: 14, score: 174
# Run: 15, score: 154
# Run: 16, score: 307
# Run: 17, score: 157
# Run: 18, score: 185
# Run: 19, score: 187
# Run: 20, score: 201
# Run: 21, score: 174
# Run: 22, score: 138
# Run: 23, score: 164
# Run: 24, score: 213
# Run: 25, score: 216
# Run: 26, score: 132
# Run: 27, score: 71
# Run: 28, score: 15
# Run: 29, score: 172
# Run: 30, score: 145
# Run: 31, score: 174
# Run: 32, score: 187
# Run: 33, score: 131
# Run: 34, score: 37
# Run: 35, score: 191
# Run: 36, score: 178
# Run: 37, score: 189
# Run: 38, score: 168
# Run: 39, score: 224
# Run: 40, score: 137
# Run: 41, score: 162
# Run: 42, score: 75
# Run: 43, score: 131
# Run: 44, score: 333
# Run: 45, score: 105
# Run: 46, score: 140
# Run: 47, score: 72
# Run: 48, score: 137
# Run: 49, score: 189
# Run: 50, score: 210
# Run: 51, score: 128
# Run: 52, score: 137
# Run: 53, score: 165
# Run: 54, score: 127
# Run: 55, score: 192
# Run: 56, score: 121
# Run: 57, score: 261
# Run: 58, score: 164
# Run: 59, score: 172
# Run: 60, score: 277
# Run: 61, score: 267
# Run: 62, score: 153
# Run: 63, score: 157
# Run: 64, score: 145
# Run: 65, score: 242
# Run: 66, score: 246
# Run: 67, score: 119
# Run: 68, score: 276
# Run: 69, score: 175
# Run: 70, score: 213
# Run: 71, score: 164
# Run: 72, score: 157
# Run: 73, score: 138
# Run: 74, score: 219
# Run: 75, score: 147
# Run: 76, score: 122
# Run: 77, score: 258
# Run: 78, score: 200
# Run: 79, score: 292
# Run: 80, score: 18
# Run: 81, score: 150
# Run: 82, score: 106
# Run: 83, score: 387
# Run: 84, score: 170
# Run: 85, score: 143
# Run: 86, score: 172
# Run: 87, score: 261
# Run: 88, score: 241
# Run: 89, score: 177
# Run: 90, score: 150
# Run: 91, score: 174
# Run: 92, score: 122
# Run: 93, score: 159
# Run: 94, score: 89
# Run: 95, score: 12
# Run: 96, score: 13
# Run: 97, score: 79
# Run: 98, score: 153
# Run: 99, score: 168
# Run: 100, score: 156
