# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
Cartpole_DQN_play = pd.read_csv('data/Cartpole_DQN_play_scores.csv',encoding = "Latin-1")
Cartpole_DQN_train = pd.read_csv('data/Cartpole_DQN_train_scores.csv',encoding = "Latin-1")

Cartpole_GA_play = pd.read_csv('data/Cartpole_GA_play_scores.csv',encoding = "Latin-1")
Cartpole_GA_train = pd.read_csv('data/Cartpole_GA_train_scores.csv',encoding = "Latin-1")

Cartpole_NS_play = pd.read_csv('data/Cartpole_NS_play_scores.csv',encoding = "Latin-1")
Cartpole_NS_train = pd.read_csv('data/Cartpole_NS_train_scores.csv',encoding = "Latin-1")

Cartpole_DQN_extended_play = pd.read_csv('data/Cartpole_DQN_extended_play_scores.csv',encoding = "Latin-1")
Cartpole_DQN_extended_train = pd.read_csv('data/Cartpole_DQN_extended_train_scores.csv',encoding = "Latin-1")

Lunar_DQN_play = pd.read_csv('data/LUNAR_DQN_play_scores.csv',encoding = "Latin-1")
Lunar_DQN_train = pd.read_csv('data/LUNAR_DQN_train_scores.csv',encoding = "Latin-1")

Lunar_GA_play = pd.read_csv('data/LUNAR_GA_play_scores.csv',encoding = "Latin-1")
Lunar_GA_train = pd.read_csv('data/LUNAR_GA_train_scores.csv',encoding = "Latin-1")

Lunar_NS_play = pd.read_csv('data/LUNAR_NS_play_scores.csv',encoding = "Latin-1")
Lunar_NS_train = pd.read_csv('data/LUNAR_NS_train_scores.csv',encoding = "Latin-1")

Lunar_DQN_extended_play = pd.read_csv('data/LUNAR_DQN_extended_play_scores.csv',encoding = "Latin-1")
Lunar_DQN_extended_train = pd.read_csv('data/LUNAR_DQN_extended_train_scores.csv',encoding = "Latin-1")

# %%
def plot_evaluation_scores(df, episodes, score, title):
        x = df[episodes] #episodes
        y = df[score] #scores
        
        plt.plot(x, y, label="score per run")
        plt.title(title)
        plt.xlabel("Runs")
        plt.ylabel("Score")
        plt.savefig("img/" + title)
        plt.close("all")

# %%
plot_evaluation_scores(Cartpole_DQN_play, "episode", "score", "Cartpole_DQN_play_plot")
plot_evaluation_scores(Cartpole_DQN_train, "episode", "score","Cartpole_DQN_train_plot")

plot_evaluation_scores(Cartpole_GA_play, "attempt", "score", "Cartpole_GA_play_plot")
plot_evaluation_scores(Cartpole_GA_train, "generation", "average fitness", "Cartpole_GA_train_plot")

plot_evaluation_scores(Cartpole_NS_play, "attempt", "score", "Cartpole_NS_play_plot")
plot_evaluation_scores(Cartpole_NS_train, "generation", "average fitness", "Cartpole_NS_train_plot")

plot_evaluation_scores(Cartpole_DQN_extended_play,"episode", "score", "Cartpole_DQN_extended_play_plot")
plot_evaluation_scores(Cartpole_DQN_extended_train, "episode", "score","Cartpole_DQN_extended_train_plot")

plot_evaluation_scores(Lunar_DQN_play,"episode", "score", "Lunar_DQN_play_plot")
plot_evaluation_scores(Lunar_DQN_train,"episode", "score", "Lunar_DQN_train_plot")

plot_evaluation_scores(Lunar_GA_play, "attempt", "score", "Lunar_GA_play_plot")
plot_evaluation_scores(Lunar_GA_train, "generation", "average fitness", "Lunar_GA_train_plot")

plot_evaluation_scores(Lunar_NS_play, "attempt","score", "Lunar_NS_play_plot")
plot_evaluation_scores(Lunar_NS_train, "generation","average fitness", "Lunar_NS_train_plot")

plot_evaluation_scores(Lunar_DQN_extended_play,"episode", "score", "Lunar_DQN_extended_play_plot")
plot_evaluation_scores(Lunar_DQN_extended_train, "episode", "score","Lunar_DQN_extended_train_plot")

# %%
CDQN = Cartpole_DQN_train
CDQNe = CDQN["episode"]
CDQNs = CDQN["score"]
CDQNeps = CDQN["epsilon"]*300

plt.plot(CDQNe, CDQNs, label= "score")
plt.plot(CDQNeps, label="epsilon * 300")
plt.xlabel("Episodes")
plt.ylabel("Score")
plt.legend()
plt.title("Cartpole_DQN_train_with_epsilon")
plt.savefig("img/Cartpole_DQN_train_with_epsilon")
plt.show()

# %%
corr_CDQN_score_epsilon = CDQNs.corr(CDQNeps) #correlation between score and epsilon values of cartpole DQN
corr_CDQN_score_epsilon
# Out:
# -0.6443151097231783

# %%
Cartpole_DQN_extended_train
# Out:
#     episode   epsilon  score
# 0         1  1.000000      9
# 1         2  1.000000      9
# 2         3  0.965521      9
# 3         4  0.918316     11
# 4         5  0.877809     10
# ..      ...       ...    ...
# 95       96  0.010000    101
# 96       97  0.010000     10
# 97       98  0.010000     41
# 98       99  0.010000      9
# 99      100  0.010000     10
#
# [100 rows x 3 columns]

# %%
CDQNE= Cartpole_DQN_extended_train
CDQNe = CDQNE["episode"]
CDQNs = CDQNE["score"]
CDQNeps = CDQNE["epsilon"]*150

plt.plot(CDQNe, CDQNs, label= "score")
plt.plot(CDQNeps, label="epsilon * 300")
plt.xlabel("Episodes")
plt.ylabel("Score")
plt.legend()
plt.title("Cartpole_DQN_extended_train_with_epsilon")
plt.savefig("img/Cartpole_DQN_extended_train_with_epsilon")
plt.show()

# %%
corr_CDQNE_score_epsilon = CDQNs.corr(CDQNeps) #correlation between score and epsilon values of cartpole DQN
corr_CDQNE_score_epsilon
# Out:
# -0.2859887806307021

# %%
CGA = Cartpole_GA_train
CGAg = CGA["generation"]
CGAavg = CGA["average fitness"]
CGAmax = CGA["max fitness"]

plt.plot(CGAg, CGAavg, label= "average fitness")
plt.plot(CGAmax, label="max fitness")
plt.xlabel("Generation")
plt.ylabel("Score")
plt.legend()
plt.title("Cartpole_GA_train_with_max_fitness")
plt.savefig("img/Cartpole_GA_train_with_max_fitness")
plt.show()

# %%
corr_CGA_avg_max = CGAavg.corr(CGAmax) #correlation between average fitness and max fitness of cartpole GA
corr_CGA_avg_max
# Out:
# nan

# %%
CNS = Cartpole_NS_train
x = CNS["generation"]
y = CNS["average fitness"]
z = CNS["maximum fitness"]

plt.plot(x, y, label= "average fitness")
plt.plot(z, label="max fitness")
plt.xlabel("Generation")
plt.ylabel("Score")
plt.legend()
plt.title("Cartpole_NS_train_with_max_fitness")
plt.savefig("img/Cartpole_NS_train_with_max_fitness")
plt.show()

# %%
corr = y.corr(z) #correlation between average fitness and max fitness of cartpole NS
corr
# Out:
# 0.7662396434500355

# %%
LDQN = Lunar_DQN_train
x = LDQN["episode"]
y = LDQN["score"]
z = LDQN["epsilon"]*300

plt.plot(x, y, label= "score")
plt.plot(z, label="epsilon * 300")
plt.xlabel("Episodes")
plt.ylabel("Score")
plt.legend()
plt.title("LUNAR_DQN_train_with_epsilon")
plt.savefig("img/LUNAR_DQN_train_with_epsilon")
plt.show()

# %%
corr = y.corr(z) #correlation between episodes and score of Lunar DQN
corr
# Out:
# -0.7367292388479624

# %%
LDQN = Lunar_DQN_extended_train
x = LDQN["episode"]
y = LDQN["score"]
z = LDQN["epsilon"]*300

plt.plot(x, y, label= "score")
plt.plot(z, label="epsilon * 300")
plt.xlabel("Episodes")
plt.ylabel("Score")
plt.legend()
plt.title("LUNAR_DQN_extended_train_with_epsilon")
plt.savefig("img/LUNAR_DQN_extended_train_with_epsilon")
plt.show()

# %%
corr = y.corr(z) #correlation between episodes and score of Lunar DQN_extended
corr
# Out:
# -0.23351611478063272

# %%
LGA = Lunar_GA_train
x = LGA["generation"]
y = LGA["average fitness"]
z = LGA["maximum fitness"]

plt.plot(x, y, label= "average fitness")
plt.plot(z, label="max fitness")
plt.xlabel("Generation")
plt.ylabel("Score")
plt.legend()
plt.title("LUNAR_GA_train_with_max_fitness")
plt.savefig("img/LUNAR_GA_train_with_max_fitness")
plt.show()

# %%
corr = y.corr(z) #correlation between average fitness and max fitness of LUNAR GA
corr
# Out:
# 0.8824617217234506

# %%
LNS = Lunar_NS_train
x = LNS["generation"]
y = LNS["average fitness"]
z = LNS["maximum fitness"]

plt.plot(x, y, label= "average fitness")
plt.plot(z, label="max fitness")
plt.xlabel("Generation")
plt.ylabel("Score")
plt.legend()
plt.title("LUNAR_NS_train_with_max_fitness")
plt.savefig("img/LUNAR_NS_train_with_max_fitness")
plt.show()

# %%
corr = y.corr(z) #correlation between average fitness and max fitness of LUNAR NS
corr
# Out:
# 0.5175147618589298

# %%
dfdqn = Cartpole_DQN_train
dfdqne = Cartpole_DQN_extended_train
dfga = Cartpole_GA_train
dfns = Cartpole_NS_train

x1 = dfdqn["episode"]
y1 = dfdqn["score"]
x2 = dfdqne["episode"]
y2 = dfdqne["score"]
x3 = dfga["generation"]
y3 = dfga["average fitness"]
x4 = dfns["generation"]
y4 = dfns["average fitness"]

plt.plot(x1, y1, label= "score DQN")
plt.plot(x2, y2, label= "score DQN extended")
plt.plot(x3, y3, label= "average fitness GA")
plt.plot(x4, y4, label= "average fitness NS")
plt.xlabel("Episodes/Generation")
plt.ylabel("Score")
plt.legend()
plt.title("Cartpole_train_all_algorithms")
plt.savefig("img/Cartpole_train_all_algorithms")
plt.show()

# %%
dfdqn = Lunar_DQN_train
dfdqne = Lunar_DQN_extended_train
dfga = Lunar_GA_train
dfns = Lunar_NS_train

x1 = dfdqn["episode"]
y1 = dfdqn["score"]
x2 = dfdqne["episode"]
y2 = dfdqne["score"]
x3 = dfga["generation"]
y3 = dfga["average fitness"]
x4 = dfns["generation"]
y4 = dfns["average fitness"]

plt.plot(x1, y1, label= "score DQN", linewidth= 0.5)
plt.plot(x2, y2, label= "score DQN extended", linewidth= 0.5)
plt.plot(x3, y3, label= "average fitness GA", linewidth= 0.5)
plt.plot(x4, y4, label= "average fitness NS", linewidth= 0.5)
plt.xlabel("Episodes/Generation")
plt.ylabel("Score")
plt.legend()
plt.title("LUNAR_train_all_algorithms")
#plt.savefig("img/LUNAR_train_all_algorithms")
plt.show()

# %%
dfdqn = Cartpole_DQN_play
dfdqne = Cartpole_DQN_extended_play
dfga = Cartpole_GA_play
dfns = Cartpole_NS_play

x1 = dfdqn["episode"]
y1 = dfdqn["score"]
x2 = dfdqne["episode"]
y2 = dfdqne["score"]
x3 = dfga["attempt"]
y3 = dfga["score"]
x4 = dfns["attempt"]
y4 = dfns["score"]

plt.plot(x1, y1, label= "score DQN")
plt.plot(x2, y2, label= "score DQN extended")
plt.plot(x3, y3, label= "score GA")
plt.plot(x4, y4, label= "score NS")
plt.xlabel("Attempt")
plt.ylabel("Score")
plt.legend()
plt.title("Cartpole_play_all_algorithms")
plt.savefig("img/Cartpole_play_all_algorithms")
plt.show()

# %%
dfdqn = Lunar_DQN_play
dfdqne = Lunar_DQN_extended_play
dfga = Lunar_GA_play
dfns = Lunar_NS_play

x1 = dfdqn["episode"]
y1 = dfdqn["score"]
x2 = dfdqne["episode"]
y2 = dfdqne["score"]
x3 = dfga["attempt"]
y3 = dfga["score"]
x4 = dfns["attempt"]
y4 = dfns["score"]

plt.plot(x1, y1, label= "score DQN")
plt.plot(x2, y2, label= "score DQN extended")
plt.plot(x3, y3, label= "score GA")
plt.plot(x4, y4, label= "score NS")
plt.xlabel("Attempt")
plt.ylabel("Score")
plt.legend()
plt.title("Lunar_play_all_algorithms")
plt.savefig("img/Lunar_play_all_algorithms")
plt.show()

# %%
dfdqn = Lunar_DQN_play
dfga = Lunar_GA_play
dfns = Lunar_NS_play

x1 = dfdqn["episode"]
y1 = dfdqn["score"]
x2 = dfga["attempt"]
y2 = dfga["score"]
x3 = dfns["attempt"]
y3 = dfns["score"]

plt.plot(x1, y1, label= "score DQN")
plt.plot(y2, label= "score GA")
#plt.plot(y3, label= "score NS")
plt.xlabel("Attempt")
plt.ylabel("Score")
plt.legend()
plt.title("Lunar_play_all_algorithms")
#plt.savefig("img/Lunar_play_all_algorithms")
plt.show()
